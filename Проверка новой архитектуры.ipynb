# %%
from EDPy import BaseClasses
import gdspy
# %matplotlib qt

# %%
# gdspy.current_library = gdspy.GdsLibrary(name='')
# cell = gdspy.Cell(name='')

# p = gdspy.Rectangle((-1,-1),(1, 1))
# p2 = gdspy.Rectangle((-1,-1),(1, 1), layer = 1)

# p.polygons += p2.polygons
# p.layers += p2.layers
# p.datatypes += p2.datatypes
# r = BaseClasses.extract(p, 0)

# # cell.add(p)
# cell.add(r)

# gdspy.LayoutViewer(library=None, cells=cell)

# %%
# import numpy as np
# arr = np.array([1,2,3])
# mask = [True, False, True]
# arr[not mask]

# %%
ng = BaseClasses.NewGeometry('')
ng = ng + gdspy.Rectangle((-10, -10),(10, 10))
ng = ng + gdspy.Rectangle((-10, -10),(10, 10), layer = 2)

obj = BaseClasses.NewGeometry('')
obj = obj + gdspy.Rectangle((-10, -10),(10, 10), layer = 1)
obj + gdspy.Rectangle((-10, -10),(10, 10), layer = 3) # так тоже работает


# ng.set_port((0, 10), 90)
# ng.translate((10, 10))
# ng
# Out:
# Object , <class 'EDPy.BaseClasses.NewGeometry'>
# position = (0.0, 0.0)
# angle = 0
# Number of Ports:0

# %%
# Out:
# Object , <class 'EDPy.BaseClasses.NewGeometry'>
# position = (0.0, 0.0)
# angle = 0
# Number of Ports:0
# Object , <class 'EDPy.BaseClasses.NewGeometry'>
# position = (0.0, 0.0)
# angle = 0
# Number of Ports:0

# %%
ng.ports[0]
# Out:
# <class 'EDPy.BaseClasses.Port'>
# Port:
# position: (10.0, 20.0)
# angle: 90
# basis:
# a: (6.123233995736766e-17, 1.0)
# o: (-1.0, 1.2246467991473532e-16)

# %%
ng.rotate(-20)
# ng

# %%
ng.ports[0]
# ИСПРАВИТЬ ОКРУГЛЕНИЕ ПОЗИЦИИ И ВЕТОРОВ ПОРТОВ
# Out:
# <class 'EDPy.BaseClasses.Port'>
# Port:
# position: (13.42, 19.397000000000002)
# angle: 70
# basis:
# a: (0.3420201433256688, 0.9396926207859083)
# o: (-0.9396926207859083, 0.3420201433256689)

# %%
p = BaseClasses.Port((0,0), 180)
ng.merge_with(p, 0)
# ng
# Здесь не досчитываюсь 180 градусов, видимо из-за округления. Вообще в merge_with что то не то происходит

# %%
ng.ports[0]
# Out:
# <class 'EDPy.BaseClasses.Port'>
# Port:
# position: (0.0, 0.0)
# angle: 0
# basis:
# a: (1.0, 0.0)
# o: (6.123233995736766e-17, 1.0)

# %%
p1 = BaseClasses.Port((0,0),0)
p2 = BaseClasses.Port((1000,0), 180)
BaseClasses.Path.get_trajectory(p1, p2, draw=True);

# %%
p1 = BaseClasses.Port((0,0),0)
p2 = BaseClasses.Port((1000,1000), 180)
BaseClasses.Path.get_trajectory(p1, p2, draw=True);

# %%
p1 = BaseClasses.Port((0,0),0)
p2 = BaseClasses.Port((1000,1000), 180+30)
BaseClasses.Path.get_trajectory(p1, p2, draw=True);

# %%
p1 = BaseClasses.Port((0,0),0)
p2 = BaseClasses.Port((1000,1000), 180-20)
BaseClasses.Path.get_trajectory(p1, p2, draw=True);

# %%
p1 = BaseClasses.Port((0,0),0)
p2 = BaseClasses.Port((1000,1000), 180-20)
BaseClasses.Path.get_trajectory(p1, p2, draw=True);

# %%
p1 = BaseClasses.Port((0,0),0)
p2 = BaseClasses.Port((1000,1000), 270-20)
BaseClasses.Path.get_trajectory(p1, p2, draw=True);

# %%
p1 = BaseClasses.Port((0,0),0)
p2 = BaseClasses.Port((1000,1000), 270+20)
BaseClasses.Path.get_trajectory(p1, p2, draw=True);

# %%
p1 = BaseClasses.Port((0,0),0)
p2 = BaseClasses.Port((1000,0), -150)
BaseClasses.Path.get_trajectory(p1, p2, draw=True);
